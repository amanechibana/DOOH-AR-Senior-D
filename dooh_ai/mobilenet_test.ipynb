# %%
### Dooh AR Senior D - AI Team - Barnatt Wu and Johnathan Vu
### Test notebook to make mobilenet model

# %%
from roboflow import Roboflow
from dotenv import load_dotenv
import os

load_dotenv()

roboflow_api_key = os.getenv("ROBOFLOW_API_KEY")
rf = Roboflow(api_key=roboflow_api_key)
project = rf.workspace("senior-d-dooh-ar").project("dooh-ar-senior-d-vnzov")
version = project.version(3)
dataset = version.download("tfrecord")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to DOOH-AR-Senior-D-3 in tfrecord:: 100%|██████████| 5/5 [00:00<00:00, 14.70it/s]

# %%
import os

project_root = os.path.dirname(os.path.abspath(__file__)) if "__file__" in globals() else os.getcwd()
dataset_dir = os.path.join(project_root, "DOOH-AR-Senior-D-3")

train_records = os.path.join(dataset_dir, "train", "objects.tfrecord")
label_map = os.path.join(dataset_dir, "train", "objects_label_map.pbtxt")

# %%
import sys
import os

# 1️⃣ Set paths
PROJECT_ROOT = os.getcwd()  # your current project folder
RESEARCH_DIR = os.path.join(PROJECT_ROOT, "tensorflow_models", "research")
SLIM_DIR = os.path.join(RESEARCH_DIR, "slim")

# Add research and slim directories to Python path
sys.path.append(RESEARCH_DIR)
sys.path.append(SLIM_DIR)

# 2️⃣ Dataset paths
DATASET_DIR = os.path.join(PROJECT_ROOT, "DOOH-AR-Senior-D-3", "train")
TRAIN_RECORD = os.path.join(DATASET_DIR, "objects.tfrecord")
LABEL_MAP = os.path.join(DATASET_DIR, "objects_label_map.pbtxt")

# 3️⃣ Pretrained model paths
PRETRAINED_DIR = os.path.join(PROJECT_ROOT, "models", "ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8")
PIPELINE_CONFIG = os.path.join(PRETRAINED_DIR, "pipeline.config")
TRAINING_DIR = os.path.join(PROJECT_ROOT, "models", "training")

# ==============================
# 4️⃣ Verify Object Detection API
# ==============================
try:
    import object_detection
    print("✅ Object Detection API detected!")
except ModuleNotFoundError as e:
    print("❌ Object Detection API NOT detected. Check protos compilation and installation.")
    print(e)

# ==============================
# 5️⃣ Optional: Print paths for verification
# ==============================
print(f"Training TFRecord: {TRAIN_RECORD}")
print(f"Label map: {LABEL_MAP}")
print(f"Pipeline config: {PIPELINE_CONFIG}")
print(f"Checkpoints directory: {TRAINING_DIR}")

from object_detection.utils import config_util
from object_detection.builders import model_builder
print("✅ Object Detection API fully working!")
# Out:
# ✅ Object Detection API detected!
# Training TFRecord: c:\Users\jonat\OneDrive\Desktop\workspace\Senior-Design\DOOH-AR-Senior-D\dooh_ai\DOOH-AR-Senior-D-3\train\objects.tfrecord
# Label map: c:\Users\jonat\OneDrive\Desktop\workspace\Senior-Design\DOOH-AR-Senior-D\dooh_ai\DOOH-AR-Senior-D-3\train\objects_label_map.pbtxt
# Pipeline config: c:\Users\jonat\OneDrive\Desktop\workspace\Senior-Design\DOOH-AR-Senior-D\dooh_ai\models\ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8\pipeline.config
# Checkpoints directory: c:\Users\jonat\OneDrive\Desktop\workspace\Senior-Design\DOOH-AR-Senior-D\dooh_ai\models\training
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 41
#      38 print(f"Pipeline config: {PIPELINE_CONFIG}")
#      39 print(f"Checkpoints directory: {TRAINING_DIR}")
# ---> 41 from object_detection.utils import config_util
# ...

# %%
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\jonat\OneDrive\Desktop\workspace\Senior-Design\DOOH-AR-Senior-D\dooh_ai\.venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\jonat\OneDrive\Desktop\workspace\Senior-Design\DOOH-AR-Senior-D\dooh_ai\.venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
# ...
